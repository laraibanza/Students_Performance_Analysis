# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# checking the shape of df
df.shape
# Out:
# (1000, 8)

# %%
# getting the insight of df
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# checking for null values
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# average score                  0
# result                         0
# dtype: int64

# %%
# checking for duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# adding the column average score based on 3 columns
df['average score']= (df['math score']+df['reading score']+df['writing score'])/3
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# adding the result column based on average score column created recently
df['result'] = df['average score'].apply(lambda x : 'Pass' if x>=60 else 'Fail')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average score result
# 995      94.000000   Pass
# 996      57.333333   Fail
# 997      65.000000   Pass
# ...

# %%
# Descriptive Statistics
df.describe()
# Out:
#        math score  reading score  writing score  average score
# count  1000.00000    1000.000000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000      67.770667
# std      15.16308      14.600192      15.195657      14.257326
# min       0.00000      17.000000      10.000000       9.000000
# 25%      57.00000      59.000000      57.750000      58.333333
# 50%      66.00000      70.000000      69.000000      68.333333
# 75%      77.00000      79.000000      79.000000      77.666667
# max     100.00000     100.000000     100.000000     100.000000

# %%
df.gender.value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
# Group wise Analysis
df.groupby('gender')['average score'].mean()
# Out:
# gender
# female    69.569498
# male      65.837483
# Name: average score, dtype: float64

# %%
# Result based on gender
df.groupby('gender')['result'].value_counts()
# Out:
# gender  result
# female  Pass      394
#         Fail      124
# male    Pass      321
#         Fail      161
# Name: count, dtype: int64

# %%
# parents education impact on results of studenrs
df.groupby('parental level of education')['result'].value_counts()
# Out:
# parental level of education  result
# associate's degree           Pass      163
#                              Fail       59
# bachelor's degree            Pass       97
#                              Fail       21
# high school                  Pass      120
#                              Fail       76
# master's degree              Pass       49
#                              Fail       10
# some college                 Pass      171
#                              Fail       55
# some high school             Pass      115
#                              Fail       64
# Name: count, dtype: int64

# %%
# Pass rate by test preparation course
df.groupby('test preparation course')['result'].value_counts()
# Out:
# test preparation course  result
# completed                Pass      298
#                          Fail       60
# none                     Pass      417
#                          Fail      225
# Name: count, dtype: int64

# %%
# test completion based on gender
df.groupby('gender')['test preparation course'].value_counts()
# Out:
# gender  test preparation course
# female  none                       334
#         completed                  184
# male    none                       308
#         completed                  174
# Name: count, dtype: int64

# %%
# gender belong to different groups
df.groupby('gender')['race/ethnicity'].value_counts()
# Out:
# gender  race/ethnicity
# female  group C           180
#         group D           129
#         group B           104
#         group E            69
#         group A            36
# male    group C           139
#         group D           133
#         group B            86
#         group E            71
#         group A            53
# Name: count, dtype: int64

# %%
# Distribution of Scores
sns.histplot(df['average score'], kde=True)
plt.title("Distribution of Average Scores")
plt.show()

# %%
# Scores by Gender
sns.barplot(x='gender', y='average score', data=df)
plt.title("Average Scores by Gender")
plt.show()

# %%
# Test Preparation Impact
sns.barplot(x='test preparation course', y='average score', data=df)
plt.title("Effect of Test Prep on Scores")
plt.show()
